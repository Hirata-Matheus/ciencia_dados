# %% [markdown]
# ## Projeto - Análise de Dados
#
# Neste projeto, vamos utilizar o conjunto de dados **Apple AppStore Apps**
#
# Encontrado por este link a base: https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps?resource=download \
#
# Exemplo de Requisição: \
# ```json
# {
#     "App_Id": "com.apple.Pages",
#     "App_Name": "Pages",
#     "AppStore_Url": "https://apps.apple.com/us/app/pages/id361309726?uo=4",
#     "Primary_Genre": "Productivity",
#     "Content_Rating": "4+",
#     "Size_Bytes": "498595840",
#     "Required_IOS_Version": "14.0",
#     "Released": "2010-04-01T20:36:57Z",
#     "Updated": "2021-09-28T15:27:20Z",
#     "Version": "11.2",
#     "Price": 0.0,
#     "Currency": "USD",
#     "Free": true,
#     "DeveloperId": 284417353,
#     "Developer": "Apple",
#     "Developer_Url": "https://apps.apple.com/us/developer/apple/id284417353?mt=12&uo=4",
#     "Developer_Website": "http://www.apple.com/pages/",
#     "Average_User_Rating": 3.40115,
#     "Reviews": 19419,
#     "Current_Version_Score": 3.40115,
#     "Current_Version_Reviews": 19419
#   }
#
# ```

# %% [markdown]
# ## Importação de Pacotes
# Para inicializar, é necessário importar alguns pacotes para desenvolvimento do projeto

# %%
import pandas as pd

# %% [markdown]
# ## Importação de Dados
# A parte inicial do projeto trata-se em analisar os dados a serem utilizados. 1° Passo iremos importar os dados

# %%
df = pd.read_csv('dados/appleAppData.csv')

# %% [markdown]
# > Nesse comando acima utilizamos uma funcao do pandas para ler um arquivo, que no nosso caso era um .csv.
#
# > No comando abaixo ele vai ler as primeiras linhas do arquivo

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# > No comando acima ele descreve o tamanho das colunas do arquivo

# %% [markdown]
# ### Tarefa 1
#
# Analisar os dados importado. Verificar os tipos de cada coluna e fazer os ajustes necessários. Verificar se existem dados duplicados, ausentes, etc.., e realizar o tratamento.

# %% [markdown]
# > No comando abaixo é possível extrair os tipos das colunas, as categorias como nulas e não nulas e a quantidade de colunas

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %%
duplicados = df.duplicated()
duplicados
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1230371    False
# 1230372    False
# 1230373    False
# 1230374    False
# 1230375    False
# Length: 1230376, dtype: bool

# %%
duplicados.sum()
# Out:
# 0

# %% [markdown]
# > No comando acima foi possível constatar que não há elementos duplicados no arquivo

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# > No comando acima, é listado todas as colunas presentes no arquivo lido

# %%
mean_df = df['Average_User_Rating'].mean()
print(mean_df)
# Out:
# 1.788386667165159

# %% [markdown]
# > No comando acima foi possivel analisar a média de Avaliações de todos os apps na Apple Store

# %%
max_numbers_avaliations = max(df['Average_User_Rating'])
print(max_numbers_avaliations)
# Out:
# 5.0

# %% [markdown]
# > No comando acima foi possível saber qual é o número máximo de avaliação que pode dar \
# > Foi feito isso pra saber qual a avaliação máxima e depois determinar a satisfação dos usuários no geral

# %%
df.to_numpy()
# Out:
# array([['com.hkbu.arc.apaper', 'A+ Paper Guide',
#         'https://apps.apple.com/us/app/a-paper-guide/id1277517387?uo=4',
#         ..., 0, 0.0, 0],
#        ['com.dmitriev.abooks', 'A-Books',
#         'https://apps.apple.com/us/app/a-books/id1031572002?uo=4', ...,
#         1, 5.0, 1],
#        ['no.terp.abooks', 'A-books',
#         'https://apps.apple.com/us/app/a-books/id1457024164?uo=4', ...,
#         0, 0.0, 0],
#        ...,
#        ['com.beelab.SoTayXayDung', 'Sổ tay Xây dựng',
#         'https://apps.apple.com/us/app/s%E1%BB%95-tay-x%C3%A2y-d%E1%BB%B1ng/id1439012350?uo=4',
#         ..., 1, 4.0, 1],
#        ['com.icc.sttb', 'Sổ tay đảng viên Thái Bình',
#         'https://apps.apple.com/us/app/s%E1%BB%95-tay-%C4%91%E1%BA%A3ng-vi%C3%AAn-th%C3%A1i-b%C3%ACnh/id1554627760?uo=4',
#         ..., 0, 0.0, 0],
#        ['com.vnptlonganios.sodiemthongminh', 'Sổ Điểm Thông Minh',
# ...

# %% [markdown]
# > No comando acima retorna em um array, em cada item corresponde a 1 linhado arquivo

# %%
df.loc[:, ["App_Name", "Primary_Genre", "Content_Rating", "Required_IOS_Version", "Price", "Version"]]
# Out:
#                            App_Name Primary_Genre Content_Rating  \
# 0                    A+ Paper Guide     Education             4+
# 1                           A-Books          Book             4+
# 2                           A-books          Book             4+
# 3                       A-F Book #1          Book             4+
# 4           A-Z Synonyms Dictionary     Reference             4+
# ...                             ...           ...            ...
# 1230371          Sесurity АdBlосkеr     Utilities             4+
# 1230372    SесurеХ VРN - Wifi Proxy     Utilities             4+
# 1230373             Sổ tay Xây dựng     Utilities             4+
# 1230374  Sổ tay đảng viên Thái Bình     Utilities             4+
# 1230375          Sổ Điểm Thông Minh     Utilities             4+
#
#         Required_IOS_Version  Price Version
# 0                        8.0   0.00   1.1.2
# 1                       10.0   0.00     1.3
# 2                        9.0   0.00   1.3.1
# ...

# %% [markdown]
# > No comando acima, é possível selecionar as colunas que desejar, que sejam mais relevantes para visualização

# %%
df.fillna(value="Não encontrado")
# Out:
#                                     App_Id                    App_Name  \
# 0                      com.hkbu.arc.apaper              A+ Paper Guide
# 1                      com.dmitriev.abooks                     A-Books
# 2                           no.terp.abooks                     A-books
# 3                 fr.antoinettefleur.Book1                 A-F Book #1
# 4         com.imonstersoft.azdictionaryios     A-Z Synonyms Dictionary
# ...                                    ...                         ...
# 1230371               com.ledtech.sadblock          Sесurity АdBlосkеr
# 1230372                    com.securex.vpn    SесurеХ VРN - Wifi Proxy
# 1230373            com.beelab.SoTayXayDung             Sổ tay Xây dựng
# 1230374                       com.icc.sttb  Sổ tay đảng viên Thái Bình
# 1230375  com.vnptlonganios.sodiemthongminh          Sổ Điểm Thông Minh
#
#                                               AppStore_Url Primary_Genre  \
# ...

# %% [markdown]
# > No comando acima, foi substituido os valores com dados indefinidos como 'Não Encontrado', no nosso caso, seria o Developr_url

# %%
df.groupby(["Primary_Genre", "Required_IOS_Version"]).sum()
# Out:
#                                       Size_Bytes   Price  Free    DeveloperId  \
# Primary_Genre Required_IOS_Version
# Book          10                    8.502989e+07    0.00     2     2971336922
#               10.0                  1.181787e+11  629.79  1131  1372223057492
#               10.1                  1.958292e+09    5.98    16    19531555326
#               10.10.0               8.787669e+07    0.00     1     1501646722
#               10.11                 2.430166e+07    4.99     0     1457142582
# ...                                          ...     ...   ...            ...
# Weather       9.0                   2.333241e+10  430.13   386   435375263590
#               9.1                   6.494628e+08   17.96    16    15692604552
#               9.2                   5.164452e+08    8.97    14    12536536798
#               9.3                   2.512831e+09   82.84    42    44101048714
#               9.3.5                 8.372429e+07    0.00     2     1994468568
# ...

# %% [markdown]
# > No comando acima, foi realizado o agrupamento de dados pelas colunas de genero e versao do IOS

# %%
df["cate_app"] = df["Primary_Genre"].astype("category")
df["cate_app"]
# Out:
# 0          Education
# 1               Book
# 2               Book
# 3               Book
# 4          Reference
#              ...
# 1230371    Utilities
# 1230372    Utilities
# 1230373    Utilities
# 1230374    Utilities
# 1230375    Utilities
# Name: cate_app, Length: 1230376, dtype: category
# Categories (26, object): ['Book', 'Business', 'Developer Tools', 'Education', ..., 'Stickers', 'Travel', 'Utilities', 'Weather']

# %% [markdown]
# > No comando acima, é possivel criar uma categorização de uma coluna existente

# %%
df.to_pickle("df-clean.pkl")
